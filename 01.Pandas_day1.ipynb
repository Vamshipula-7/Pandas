# %%
import pandas as pd

# %%
#Csv file -comma separated value file

# %%
data=pd .read_csv('addresses.csv')

# %%
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#to read specific lines
data.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
data.head(6)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
# 5   6            6      800 Middle Avenue       NaN    Menlo Park
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US
# 5             CA  94025-9881      US

# %%
data.tail()
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.tail(7)
# Out:
#     id  location_id                   address_1  address_2  \
# 14  15           15        1500 Valencia Street        NaN
# 15  16           16         1161 South Bernardo        NaN
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 14        San Francisco             CA       94110      US
# 15            Sunnyvale             CA       94087      US
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
#column names
data.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
data.head(3)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US

# %%
#only one single coloumn (DataFrame
data[['state_province']]
# Out:
#    state_province
# 0              CA
# 1              CA
# 2              CA
# 3              CA
# 4              CA
# 5              CA
# 6              CA
# 7              CA
# 8              CA
# 9              CA
# 10             CA
# 11             CA
# 12             CA
# 13             CA
# 14             CA
# 15             CA
# 16             CA
# 17             CA
# 18             CA
# 19             CA
# 20             CA

# %%
type(data[['state_province']])
# Out:
# pandas.core.frame.DataFrame

# %%
#another way (series)
data['state_province']
# Out:
# 0     CA
# 1     CA
# 2     CA
# 3     CA
# 4     CA
# 5     CA
# 6     CA
# 7     CA
# 8     CA
# 9     CA
# 10    CA
# 11    CA
# 12    CA
# 13    CA
# 14    CA
# 15    CA
# 16    CA
# 17    CA
# 18    CA
# 19    CA
# 20    CA
# Name: state_province, dtype: object

# %%
type(data['state_province'])
# Out:
# pandas.core.series.Series

# %%
data[['city','location_id']]
# Out:
#                    city  location_id
# 0          Redwood City            1
# 1             San Mateo            2
# 2             San Mateo            3
# 3             San Mateo            4
# 4             San Mateo            5
# 5            Menlo Park            6
# 6            Menlo Park            7
# 7            Menlo Park            8
# 8          Redwood City            9
# 9          Redwood City           10
# 10         Redwood City           11
# 11         Redwood City           12
# 12         Redwood City           13
# 13         Redwood City           14
# 14        San Francisco           15
# 15            Sunnyvale           16
# 16  South San Francisco           17
# 17         Redwood City           18
# 18            San Mateo           19
# 19              Belmont           21
# 20        San Francisco           22

# %%
#only looking for id and adress1 columns
data[['id','address_1']]
# Out:
#     id                   address_1
# 0    1       2600 Middlefield Road
# 1    2            24 Second Avenue
# 2    3            24 Second Avenue
# 3    4            24 Second Avenue
# 4    5            24 Second Avenue
# 5    6           800 Middle Avenue
# 6    7              500 Arbor Road
# 7    8           800 Middle Avenue
# 8    9       2510 Middlefield Road
# 9   10       1044 Middlefield Road
# 10  11         2140 Euclid Avenue.
# 11  12       1044 Middlefield Road
# 12  13         399 Marine Parkway.
# 13  14          660 Veterans Blvd.
# 14  15        1500 Valencia Street
# 15  16         1161 South Bernardo
# 16  17     409 South Spruce Avenue
# 17  18            114 Fifth Avenue
# 18  19         19 West 39th Avenue
# 19  20          123 El Camino Real
# 20  21  2013 Avenue of the fellows

# %%
#Accesing Excel file

# %%
data1=pd.read_excel('airline.xls')

# %%
data1
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
data1.head()
# Out:
#    YEAR      Y      W       R      L      K
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574

# %%
#read data from sheet 1 ,sheet 2,sheet 3
pd.read_excel('airline1.xls')
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
# not to give data as heading use (header=None)
pd.read_excel("airline1.xls" , sheet_name = "Sheet2", header=None)
# Out:
#        0       1      2       3      4      5
# 0   1958   4.563  0.391  0.3284  2.706  1.067
# 1   1959   5.385  0.426  0.3856  2.846  1.083
# 2   1960   5.554  0.441  0.3193  3.089  1.481
# 3   1961   5.465  0.460  0.3079  3.122  1.736
# 4   1962   5.825  0.485  0.3783  3.184  1.926
# 5   1963   6.876  0.506  0.4180  3.263  2.041
# 6   1964   7.823  0.538  0.5163  3.412  1.997
# 7   1965   9.120  0.564  0.5879  3.623  2.257
# 8   1966  10.512  0.586  0.5369  4.074  2.742
# 9   1967  13.020  0.622  0.4443  4.710  3.564
# 10  1968  15.261  0.666  0.3052  5.217  4.767
# 11  1969  16.313  0.731  0.2332  5.569  6.511
# 12  1970  16.002  0.831  0.1883  5.495  7.627

# %%
#to give heading which dont have headers
k=pd.read_excel('airline1.xls',sheet_name="Sheet3",header=None,names=["a","b","c","d","e","f"])

# %%
k
# Out:
#        a      b      c       d      e      f
# 0   1948  1.214  0.243  0.1454  1.415  0.612
# 1   1949  1.354  0.260  0.2181  1.384  0.559
# 2   1950  1.569  0.278  0.3157  1.388  0.573
# 3   1951  1.948  0.297  0.3940  1.550  0.564
# 4   1952  2.265  0.310  0.3559  1.802  0.574
# 5   1953  2.731  0.322  0.3593  1.926  0.711
# 6   1954  3.025  0.335  0.4025  1.964  0.776
# 7   1955  3.562  0.350  0.3961  2.116  0.827
# 8   1956  3.979  0.361  0.3822  2.435  0.800
# 9   1957  4.420  0.379  0.3045  2.707  0.921
# 10  1958  4.563  0.391  0.3284  2.706  1.067

# %%
#save a file
k.to_csv("test1.csv",index=False)

# %%
k.to_excel("test2.xlsx")

# %%
k.head()
# Out:
#       a      b      c       d      e      f
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574

# %%
k.tail()
# Out:
#        a      b      c       d      e      f
# 6   1954  3.025  0.335  0.4025  1.964  0.776
# 7   1955  3.562  0.350  0.3961  2.116  0.827
# 8   1956  3.979  0.361  0.3822  2.435  0.800
# 9   1957  4.420  0.379  0.3045  2.707  0.921
# 10  1958  4.563  0.391  0.3284  2.706  1.067

# %%
k.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
list(k.columns)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
k[['a','b']]
# Out:
#        a      b
# 0   1948  1.214
# 1   1949  1.354
# 2   1950  1.569
# 3   1951  1.948
# 4   1952  2.265
# 5   1953  2.731
# 6   1954  3.025
# 7   1955  3.562
# 8   1956  3.979
# 9   1957  4.420
# 10  1958  4.563

# %%
#to read comma separated file directly, without uploading 
titanic=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[["Name"]]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/iNeuronai/sql-and-mongo/main/glass.data")
# Out:
#      index       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Class
# 0        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1        2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3        4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..     ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209    210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210    211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211    212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212    213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213    214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]

# %%
# !pip install lxml

# %%
data2=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2023_per_game.html")

# %%
type(data2)
# Out:
# list

# %%
data2
# Out:
# [      Rk              Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
#  0      1    Precious Achiuwa   C  23  TOR  40  11  22.7  3.8   7.9  ...  .689
#  1      2        Steven Adams   C  29  MEM  42  42  27.0  3.7   6.3  ...  .364
#  2      3         Bam Adebayo   C  25  MIA  58  58  34.9  8.4  15.6  ...  .803
#  3      4        Ochai Agbaji  SG  22  UTA  40   3  15.7  1.9   3.9  ...  .682
#  4      5        Santi Aldama  PF  22  MEM  58  18  21.9  3.3   7.0  ...  .729
#  ..   ...                 ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
#  649  507  McKinley Wright IV  PG  24  DAL  20   1  10.3  1.2   2.5  ...  .636
#  650  508      Thaddeus Young  PF  34  TOR  51   9  15.3  2.1   3.8  ...  .692
#  651  509          Trae Young  PG  24  ATL  55  55  35.3  8.5  19.9  ...  .889
#  652  510         Cody Zeller   C  30  MIA   4   0  15.5  2.0   3.3  ...  .667
#  653  511         Ivica Zubac   C  25  LAC  60  60  29.4  4.0   6.5  ...  .703
#
# ...

# %%
#To know how many tables are available
len(data2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 #To know how many tables are available
# ----> 2 len(data2)
#
# NameError: name 'data2' is not defined

# %%
#to extract the table
data2[0]
# Out:
#       Rk              Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1    Precious Achiuwa   C  23  TOR  40  11  22.7  3.8   7.9  ...  .689
# 1      2        Steven Adams   C  29  MEM  42  42  27.0  3.7   6.3  ...  .364
# 2      3         Bam Adebayo   C  25  MIA  58  58  34.9  8.4  15.6  ...  .803
# 3      4        Ochai Agbaji  SG  22  UTA  40   3  15.7  1.9   3.9  ...  .682
# 4      5        Santi Aldama  PF  22  MEM  58  18  21.9  3.3   7.0  ...  .729
# ..   ...                 ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 649  507  McKinley Wright IV  PG  24  DAL  20   1  10.3  1.2   2.5  ...  .636
# 650  508      Thaddeus Young  PF  34  TOR  51   9  15.3  2.1   3.8  ...  .692
# 651  509          Trae Young  PG  24  ATL  55  55  35.3  8.5  19.9  ...  .889
# 652  510         Cody Zeller   C  30  MIA   4   0  15.5  2.0   3.3  ...  .667
# 653  511         Ivica Zubac   C  25  LAC  60  60  29.4  4.0   6.5  ...  .703
#
# ...

# %%
data2[0].to_csv("players.csv")

# %%
#to extract only  average age
